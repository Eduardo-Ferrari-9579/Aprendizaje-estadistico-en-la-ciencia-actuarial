# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Emision.csv',sep=';',engine='python')
df
# Out:
#         Entidad Marca  Tipo de Vehiculo Forma de Venta  Cobertura  \
# 0           N/D   N/D                 1            N/D          1
# 1           N/D   N/D                 1            N/D          1
# 2           N/D   N/D                 1            N/D          1
# 3           N/D   N/D                 1            N/D          1
# 4           N/D   N/D                 1            N/D          1
# ...         ...   ...               ...            ...        ...
# 1048570      12  0814                 1             05          2
# 1048571      12  0814                 1             05          2
# 1048572      12  0814                 1             05          3
# 1048573      12  0814                 1             05          4
# 1048574      12  0814                 1             05          5
#
#         Subtipo de Seguro  Deducible  Numero de Vehiculos  Prima Emitida  \
# 0                     N/D          0                  250       40756.50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Entidad                    1048575 non-null  object
#  1   Marca                      1048575 non-null  object
#  2   Tipo de Vehiculo           1048575 non-null  int64
#  3   Forma de Venta             1048575 non-null  object
#  4   Cobertura                  1048575 non-null  int64
#  5   Subtipo de Seguro          1048575 non-null  object
#  6   Deducible                  1048575 non-null  int64
#  7   Numero de Vehiculos        1048575 non-null  int64
#  8   Prima Emitida              1048575 non-null  float64
#  9   Prima Cedida               1048575 non-null  float64
#  10  Prima Devengada            1048575 non-null  float64
#  11  Comision Directa           1048575 non-null  int64
# ...

# %%
df.pop('Deducible')
# Out:
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#            ..
# 1048570     5
# 1048571    10
# 1048572     0
# 1048573     0
# 1048574     0
# Name: Deducible, Length: 1048575, dtype: int64

# %%
for i in list(df.columns):
    df.loc[df[i]=='N/D',i]=np.nan
df.head()
# Out:
#   Entidad Marca  Tipo de Vehiculo Forma de Venta  Cobertura Subtipo de Seguro  \
# 0     NaN   NaN               1.0            NaN        1.0               NaN
# 1     NaN   NaN               1.0            NaN        1.0               NaN
# 2     NaN   NaN               1.0            NaN        1.0               NaN
# 3     NaN   NaN               1.0            NaN        1.0               NaN
# 4     NaN   NaN               1.0            NaN        1.0               NaN
#
#    Numero de Vehiculos  Prima Emitida  Prima Cedida  Prima Devengada  \
# 0                250.0       40756.50           0.0              0.0
# 1                232.0      120337.27           0.0              0.0
# 2                516.0      152104.14           0.0              0.0
# 3                555.0      175783.33           0.0              0.0
# 4                354.0       96324.72           0.0              0.0
#
#    Comision Directa  Suma Asegurada  Prima Devengada Acumulada
# ...

# %%
df.dropna(inplace=True)
df.head()
# Out:
#     Entidad Marca  Tipo de Vehiculo Forma de Venta  Cobertura  \
# 123      01  0001               1.0             01        1.0
# 124      01  0001               1.0             01        1.0
# 125      01  0001               1.0             01        1.0
# 126      01  0001               1.0             01        2.0
# 127      01  0001               1.0             01        2.0
#
#     Subtipo de Seguro  Numero de Vehiculos  Prima Emitida  Prima Cedida  \
# 123                 0                 56.0       81029.21           0.0
# 124                 0                225.0      200445.76           0.0
# 125                 0                  4.0        3667.70           0.0
# 126                 0                  9.0        5583.87           0.0
# 127                 0                 39.0       14776.44           0.0
#
#      Prima Devengada  Comision Directa  Suma Asegurada  \
# 123         72331.15            8105.0             0.0
# ...

# %%
df[['Cobertura','Tipo de Vehiculo']]=df[['Cobertura','Tipo de Vehiculo']].astype(int)
df[['Cobertura','Tipo de Vehiculo','Entidad','Marca','Subtipo de Seguro']]=df[['Cobertura','Tipo de Vehiculo','Entidad','Marca','Subtipo de Seguro']].astype('category')

# %%
df
# Out:
#         Entidad Marca Tipo de Vehiculo Forma de Venta Cobertura  \
# 123          01  0001                1             01         1
# 124          01  0001                1             01         1
# 125          01  0001                1             01         1
# 126          01  0001                1             01         2
# 127          01  0001                1             01         2
# ...         ...   ...              ...            ...       ...
# 1048570      12  0814                1             05         2
# 1048571      12  0814                1             05         2
# 1048572      12  0814                1             05         3
# 1048573      12  0814                1             05         4
# 1048574      12  0814                1             05         5
#
#         Subtipo de Seguro  Numero de Vehiculos  Prima Emitida  Prima Cedida  \
# 123                     0                 56.0       81029.21          0.00
# ...

# %% [markdown]
# En el primer renglón tenemos que el 56 pólizas estuvieron expuestas durante el periodo de reporte en Aguascalientes, de la marca General Motors del tipo CHEVELLE NOVA CAPRICE OPEL, las cuales se vendieron mediante agentes físicos con tipo de cobertura de Daños materiales. De este total se emitieron
