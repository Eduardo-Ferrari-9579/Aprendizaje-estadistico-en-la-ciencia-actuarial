# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Siniestros.csv',sep=';',engine='python')

# %%
df
# Out:
#        Tipo de Vehiculo Marca Deducible  Cobertura  Entidad  Tipo de Perdida  \
# 0                   N/D   N/D       N/D          1        1                1
# 1                   N/D   N/D       N/D          1        1                1
# 2                   N/D   N/D       N/D          1        1                2
# 3                   N/D   N/D       N/D          1        1                2
# 4                   N/D   N/D       N/D          1        1                2
# ...                 ...   ...       ...        ...      ...              ...
# 462562               01  0073       N/D          4        7                3
# 462563               01  0477         0          4       15                3
# 462564               01  0266         0          4        8                3
# 462565               16  7549        25          4        8                7
# 462566               01  0151         0          4       24                3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462567 entries, 0 to 462566
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Tipo de Vehiculo     462567 non-null  object
#  1   Marca                462567 non-null  object
#  2   Deducible            462567 non-null  object
#  3   Cobertura            462567 non-null  int64
#  4   Entidad              462567 non-null  int64
#  5   Tipo de Perdida      462567 non-null  int64
#  6   Subtipo de Seguro    462567 non-null  object
#  7   Causa del siniestro  462567 non-null  int64
#  8   Numero de Vehiculos  462567 non-null  int64
#  9   Monto de Siniestros  462567 non-null  float64
#  10  Monto Pagado         462567 non-null  float64
#  11  Salvamentos          462567 non-null  float64
#  12  Gastos de Ajuste     462567 non-null  float64
#  13  Monto de Deducible   462567 non-null  float64
#  14  Monto Reaseguro      462567 non-null  float64
# ...

# %%
df.pop('Deducible')
# Out:
# 0         N/D
# 1         N/D
# 2         N/D
# 3         N/D
# 4         N/D
#          ...
# 462562    N/D
# 462563      0
# 462564      0
# 462565     25
# 462566      0
# Name: Deducible, Length: 462567, dtype: object

# %%
for i in list(df.columns):
    df.loc[df[i]=='N/D',i]=np.nan

# %%
#df.loc[df['Tipo de Vehiculo']=='N/D','Tipo de Vehiculo']=np.nan
df.head()
# Out:
#   Tipo de Vehiculo Marca  Cobertura  Entidad  Tipo de Perdida  \
# 0              NaN   NaN        1.0      1.0              1.0
# 1              NaN   NaN        1.0      1.0              1.0
# 2              NaN   NaN        1.0      1.0              2.0
# 3              NaN   NaN        1.0      1.0              2.0
# 4              NaN   NaN        1.0      1.0              2.0
#
#   Subtipo de Seguro  Causa del siniestro  Numero de Vehiculos  \
# 0               NaN                  6.0               1278.0
# 1               NaN                 12.0                 17.0
# 2               NaN                  6.0                 46.0
# 3               NaN                  7.0                  1.0
# 4               NaN                 12.0                  2.0
#
#    Monto de Siniestros  Monto Pagado  Salvamentos  Gastos de Ajuste  \
# 0           -479622.47     313772.21   -204444.00          71730.21
# 1             -8934.00          0.00         0.00              0.00
# ...

# %%
df.dropna(inplace=True)

# %%
df[['Cobertura','Entidad','Tipo de Perdida','Subtipo de Seguro','Causa del siniestro']]=df[['Cobertura','Entidad','Tipo de Perdida','Subtipo de Seguro','Causa del siniestro']].astype(int)

# %%
df[['Tipo de Vehiculo','Marca','Cobertura','Entidad','Tipo de Perdida','Subtipo de Seguro','Causa del siniestro']]=df[['Tipo de Vehiculo','Marca','Cobertura','Entidad','Tipo de Perdida','Subtipo de Seguro','Causa del siniestro']].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 461461 entries, 869 to 462566
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Tipo de Vehiculo     461461 non-null  category
#  1   Marca                461461 non-null  category
#  2   Cobertura            461461 non-null  category
#  3   Entidad              461461 non-null  category
#  4   Tipo de Perdida      461461 non-null  category
#  5   Subtipo de Seguro    461461 non-null  category
#  6   Causa del siniestro  461461 non-null  category
#  7   Numero de Vehiculos  461461 non-null  float64
#  8   Monto de Siniestros  461461 non-null  float64
#  9   Monto Pagado         461461 non-null  float64
#  10  Salvamentos          461461 non-null  float64
#  11  Gastos de Ajuste     461461 non-null  float64
#  12  Monto de Deducible   461461 non-null  float64
#  13  Monto Reaseguro      461461 non-null  float64
# ...

# %%
df
# Out:
#        Tipo de Vehiculo Marca Cobertura Entidad Tipo de Perdida  \
# 869                  01  0001         1       1               1
# 870                  01  0001         1       2               1
# 871                  01  0001         1       2               4
# 872                  01  0001         1       3               1
# 873                  01  0001         1       4               1
# ...                 ...   ...       ...     ...             ...
# 462562               01  0073         4       7               3
# 462563               01  0477         4      15               3
# 462564               01  0266         4       8               3
# 462565               16  7549         4       8               7
# 462566               01  0151         4      24               3
#
#        Subtipo de Seguro Causa del siniestro  Numero de Vehiculos  \
# 869                    0                   6                  1.0
# ...

# %% [markdown]
# En el primer reglón tenemos que 1 vehículo, automóvil, General Motors tipo CHEVELLE NOVA CAPRICE OPEL, con tipo de cobertura: daños materiales, Entidad= Aguascalientes, con pérdida parcial, siniestro derivado de una colisión tuvo un monto de siniestro de menor al valor asignado por lo que al realizar ajustes se registró con negativo.

# %%
tipo_cobertura=df.groupby(['Cobertura','Tipo de Vehiculo','Marca','Entidad'])

# %%
df_resum=pd.DataFrame(tipo_cobertura.size())

# %%
df_resum
# Out:
#                                            0
# Cobertura Tipo de Vehiculo Marca Entidad
# 1         01               0001  1         7
#                                  2        17
#                                  3         7
#                                  4         9
#                                  5        17
# ...                                       ..
# 99        99               9999  29        0
#                                  30        0
#                                  31        0
#                                  32        0
#                                  33        0
#
# [8365896 rows x 1 columns]

# %%
df_resum.iloc[3]
# Out:
# 0    8
# Name: (1, 01, 0002, 1), dtype: int64
